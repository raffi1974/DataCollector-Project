# %%
import pandas as pd
import numpy as np
import os
import json
import difflib

# %% [markdown]
# ### get the dictionary dimensions and values to verify schema

# %%
path='C:/Users/RSHIRINI/OneDrive - United Nations/Desktop/DSS/DATA COLLECTOR'

df_translation=pd.read_excel(path+'/translation dict.xlsx')

''' it will create such a structure
{
    "Country": {
        "dim_values": {
            "Egypt": "مصر",
            "Lebanon": "لبنان"
        },
        "dim": {
            "Country": "البلد"
        }
    }
}'''

En_Ar_dictionary={}
#get the unique dimensions
dimensions = set(df_translation['col_en'].unique())

for dim in dimensions:
    df_dim=df_translation[df_translation['col_en'].isin([dim.lower(), dim])].copy()
    En_Ar_dictionary.update(
        {dim:{'dim_values':dict(zip(df_dim['val_en'], df_dim['val_ar'])), 
                'dim': {df_dim['col_en'].unique()[0]:df_dim['col_ar'].unique()[0]}}})

Ar_En_dictionary={}
#get the unique dimensions
dimensions = set(df_translation['col_ar'].unique())

for dim in dimensions:
    df_dim=df_translation[df_translation['col_ar'].isin([dim.lower(), dim])].copy()
    Ar_En_dictionary.update(
        {dim:{'dim_values':dict(zip(df_dim['val_ar'], df_dim['val_en'])), 
                'dim': {df_dim['col_ar'].unique()[0]:df_dim['col_en'].unique()[0]}}})

# %%
Ar_En_dictionary.keys()
# Out:
# dict_keys(['المواطنة', 'المنطقة', 'القطاع المؤسسي', 'المصدر', 'أسباب البقاء خارج القوى العاملة', 'مصدر مياه الشرب', 'السنة', 'نوع حيازة الوحدات السكنية', 'الفصل', 'القطاع', 'الجنس', 'المؤشر', 'العدد', 'أقسام المهن الرئيسية', 'الدولة', 'الفئة', 'التصنيف الدولي لاسباب الوفاة', 'أنواع نظام التخلص من مياه الصرف الصحي', 'أقسام النشاط الإقتصادي', 'الفئة العمرية', 'الحالة الزوجية', 'المرحلة التعليمية', 'مصدر الإضاءة', 'نوع مكان الإقامة', 'نوع\xa0الخدمات/المنتجات', 'وضع العمالة', 'سبب الوفاة'])

# %% [markdown]
# ### Processing ALL questionnaires

# %%
# main_path='C:/Users/RSHIRINI/OneDrive - United Nations/Desktop/DSS/DATA COLLECTOR/datacollector_received_quest/recieved_quests'
#loop over folders, merge and save as separate files

folders=['Population']
# folders=['Population', 'Labor','Housing','Education','Health','Poverty']
main_path='C:/Users/RSHIRINI/OneDrive - United Nations/Desktop/DSS/DATA COLLECTOR/datacollector_received_quest'
# folder_path='C:/Users/RSHIRINI/OneDrive - United Nations/Desktop/DSS/DATA COLLECTOR'

for folder in folders:
    folder_path=f'{main_path}/{folder}'
    # Get all excel files in the directory
    xlsx_files = [f for f in os.listdir(folder_path) if f.endswith('.xlsx')]

    print(f'Processing {folder}')
    print('//////////////////////////////////////// \n')

    dataframes = []

    category_map = {
        'housing': 'سكن',
        'population': 'سكان',
        'labor': 'عمالة',
        'education': 'التعليم',
        'poverty': 'الفقر',
        'health': 'الصحة'
    }

    #adding الفصل to the dictionary
    Ar_En_dictionary['الفصل'] = {'dim_values': {v: k for k, v in category_map.items()}}

    for file in xlsx_files:
        print(f'\n -----------------------------Processing {file}----------------------------------------')
        xls = pd.ExcelFile(os.path.join(folder_path, file))
        
        for sheet_name in xls.sheet_names:
            print(f'Processing {sheet_name}\n')
            df_raw = pd.read_excel(xls, sheet_name=sheet_name, header=None, dtype=str)
            header_rows = df_raw.index[df_raw[0] == 'index'].tolist()
            if len(header_rows) < 2: continue

            # 1. prepare the data and source slices
            df_data = df_raw[df_raw[0] == '1'].copy()
            df_data.columns = df_raw.iloc[header_rows[0]].dropna().str.strip()
            # Drop index now
            df_data = df_data.drop(columns=['index'], errors='ignore')
            
            df_source = df_raw[df_raw[0] == '2'].copy()
            df_source = df_source[df_raw.iloc[header_rows[1]].dropna().str.strip().index]
            df_source.columns = df_raw.iloc[header_rows[1]].dropna().str.strip()
            # Drop index now
            df_source = df_source.drop(columns=['index'], errors='ignore')

            ###########################################################################################
            # Extract category and add 'الفصل' column
            def extract_category(sheet_name):
                # Normalize: if there is a '-', take the part after it, otherwise use the whole name
                target = sheet_name.split('-')[-1].strip()
        
                # Now extract the part before the underscore (if it exists)
                return target.split('_')[0].strip().lower()

            raw_cat = extract_category(sheet_name)

            # If raw_cat is not in keys, try to find the best match using difflib
            if raw_cat not in category_map.keys():
                matches = difflib.get_close_matches(raw_cat, category_map.keys(), n=1, cutoff=0.6)
                if matches:
                    best_match = matches[0]
                    print(f"  >> FIX CATEGORY: {raw_cat} -> {best_match}")
                    raw_cat = best_match
                else:
                    print(f'  !!! ERROR: Could not identify category for {raw_cat} from {file}')

            # Assign the value based on the (potentially fixed) raw_cat
            df_data['الفصل'] = category_map.get(raw_cat, raw_cat)

            ########################################################################################################
        
            # --- 3. merge data with source ---
            # id_vars are all non-digit columns (Indicator, Country, Chapter, etc.)
            id_vars = [c for c in df_data.columns if not str(c).isdigit()]
            # year_columns are only the digit columns (2010, 2011, etc.)
            year_columns = [c for c in df_data.columns if str(c).isdigit()]
            
            #DEBUG############
            # print(sheet_name)
            #DEBUG############

            df_melted = df_data.melt(
                id_vars=id_vars, 
                value_vars=year_columns, 
                var_name='السنة', 
                value_name='العدد'
            )

            # CRASH LOCATOR BLOCK
            try:
                # Merge melted data with source info
                df_merged = pd.merge(df_melted, df_source, on=['السنة', 'المؤشر', 'الدولة'], how='left')
                
                
            except KeyError as e:
                print("\n" + "="*50)
                print(f"💥 CRASH DETECTED IN WORKBOOK: {file}")
                print(f"💥 ON SHEET: {sheet_name}")
                print(f"💥 FOR CHAPTER ('الفصل'): {df_data['الفصل'].iloc[0] if 'الفصل' in df_data.columns else 'Unknown'}")
                print("="*50)
                print(f"Columns actually found in df_data:\n{list(df_data.columns)}\n")
                print(f"Columns actually found in df_source:\n{list(df_source.columns)}")
                print("="*50)
                raise e
            
            ###############################################################################################################        
            # --- CLEANING BLOCK ---

            # Added 'الفصل' to keep it from being changed/fixed
            standard_cols = {'السنة', 'العدد', 'المصدر', 'الفصل'}
            
            # 1. Column Name Cleanup
            search_targets = list(standard_cols) + list(Ar_En_dictionary.keys())
            
            for col in list(df_merged.columns):
                match = difflib.get_close_matches(str(col), search_targets, n=1, cutoff=0.6)
                if match and match[0] != col:
                    best_match = match[0]
                    print(f"  >> FIX COL: {sheet_name} : {col}({len(str(col))} chars) -> {best_match} ({len(str(best_match))} chars)")
                    df_merged.rename(columns={col: best_match}, inplace=True)
                    
            # 2. Cell Value Cleanup
            for col in df_merged.columns:
                # Note: Ensuring column exists in dict to avoid KeyError
                if col in Ar_En_dictionary:
                    allowed_vals = [str(k) for k in Ar_En_dictionary[col]['dim_values'].keys()]
                    
                    for val in df_merged[col].unique():
                        if str(val) not in allowed_vals:
                            v_match = difflib.get_close_matches(str(val), allowed_vals, n=1, cutoff=0.6)
                            if v_match and v_match[0] != str(val):
                                print(f"FIX VAL: [{sheet_name} : {col}] {val} ({len(str(val))} chars) -> {v_match[0]} ({len(str(v_match[0]))} chars)")
                                df_merged[col] = df_merged[col].replace(val, v_match[0])
                else:
                    print(f'{col} was not found in the dictionary')

            #append to the dataframes
            dataframes.append(df_merged)
                                
            ########################################################################################################
    # Final aggregation
    path='C:/Users/RSHIRINI/OneDrive - United Nations/Desktop/DSS/COMPENDIUM-ARAB SOCIETY'

    final_df = pd.concat(dataframes, ignore_index=True)
    
    # One last safety strip in case different sheets had different trailing spaces 
    # that survived the merge or concat
    final_df.columns = final_df.columns.str.strip()
    
    final_df = final_df.dropna(axis=1, how='all')
    final_df.to_excel(path+f'/{folder}_AR_replied.xlsx', index=False)

    print('########################################\n\n')
# Out:
# Processing Population
# ////////////////////////////////////////
#
#
#  -----------------------------Processing Algeria population.xlsx----------------------------------------
# Processing Population_19_b
#
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_21_a
#
# Processing Population_23_a
#
# FIX VAL: [Population_23_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# Processing Population_13_b
#
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# Processing Population_20_a
#
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_18_a
#
# Processing Population_23_b
#
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# Processing Population_20_b
#
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_18
#
# Processing Population_22
#
# Processing Population_15
#
# Processing Population_13_a
#
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# Processing Population_19_a
#
# Processing Population_18_b
#
# Processing Population_21_b
#
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_17
#
# FIX VAL: [Population_17 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_16
#
# Processing Population_14
#
# Processing Population_12_b
#
# Processing Population_9_b
#
# Processing Population_10_a
#
# Processing Population_10_b
#
# Processing Population_9_a
#
# Processing Population_12_a
#
# Processing Population_11
#
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# Processing Population_8_b
#
# FIX VAL: [Population_8_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_8_a
#
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_7_b2
#
# FIX VAL: [Population_7_b2 : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (%) (46 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_b1
#
# FIX VAL: [Population_7_b1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_a2
#
# FIX VAL: [Population_7_a2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_a1
#
# FIX VAL: [Population_7_a1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_6_b
#
# Processing Population_6_a
#
# Processing Population_5_b
#
# Processing Population_5_a
#
# Processing Population_3
#
# Processing Population_4
#
# Processing Population_2
#
# Processing Population_1_b
#
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_1_a
#
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
#
#  -----------------------------Processing Bahrain population.xlsx----------------------------------------
# Processing Population_1_a
#
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_1_b
#
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_2
#
# Processing Population_3
#
# Processing Population_4
#
# Processing Population_5_a
#
# Processing Population_5_b
#
# Processing Population_6_a
#
# Processing Population_6_b
#
# Processing Population_7_a1
#
# FIX VAL: [Population_7_a1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_a2
#
# FIX VAL: [Population_7_a2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_b1
#
# FIX VAL: [Population_7_b1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_b2
#
# FIX VAL: [Population_7_b2 : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (42 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_8_a
#
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_8_b
#
# FIX VAL: [Population_8_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_9_a
#
# Processing Population_9_b
#
# Processing Population_10_a
#
# Processing Population_10_b
#
# Processing Population_11
#
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# Processing Population_12_a
#
# Processing Population_12_b
#
# Processing Population_13_a
#
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# Processing Population_13_b
#
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# Processing Population_14
#
# Processing Population_15
#
# Processing Population_16
#
# Processing Population_17
#
# FIX VAL: [Population_17 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_18
#
# Processing Population_18_a
#
# Processing Population_18_b
#
# Processing Population_19_a
#
# Processing Population_19_b
#
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_20_a
#
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_20_b
#
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_21_a
#
# Processing Population_21_b
#
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_22
#
# Processing Population_23_a
#
# FIX VAL: [Population_23_a  : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# Processing Population_23_b
#
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
#
#  -----------------------------Processing Comoros Population.xlsx----------------------------------------
# Processing Population_1_a
#
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_1_b
#
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_2
#
# Processing Population_3
#
# Processing Population_4
#
# Processing Population_5_a
#
# Processing Population_5_b
#
# Processing Population_6_a
#
# Processing Population_6_b
#
# Processing Population_7_a1
#
# FIX VAL: [Population_7_a1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_a2
#
# FIX VAL: [Population_7_a2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_b1
#
# FIX VAL: [Population_7_b1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_b2
#
# FIX VAL: [Population_7_b2 : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (%) (46 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_8_a
#
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_8_b
#
# FIX VAL: [Population_8_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_9_a
#
# Processing Population_9_b
#
# Processing Population_10_a
#
# Processing Population_10_b
#
# Processing Population_11
#
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# Processing Population_12_a
#
# Processing Population_12_b
#
# Processing Population_13_a
#
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# Processing Population_13_b
#
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# Processing Population_14
#
# Processing Population_15
#
# Processing Population_16
#
# Processing Population_17
#
# FIX VAL: [Population_17 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_18
#
# Processing Population_18_a
#
# Processing Population_18_b
#
# Processing Population_19_a
#
# Processing Population_19_b
#
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_20_a
#
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_20_b
#
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_21_a
#
# Processing Population_21_b
#
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_22
#
# Processing Population_23_a
#
# FIX VAL: [Population_23_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# Processing Population_23_b
#
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
#
#  -----------------------------Processing Djibouti Population.xlsx----------------------------------------
# Processing Population_1_a
#
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_1_b
#
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_2
#
# Processing Population_3
#
# Processing Population_4
#
# Processing Population_5_a
#
# Processing Population_5_b
#
# Processing Population_6_a
#
# Processing Population_6_b
#
# Processing Population_7_a
#
# FIX VAL: [Population_7_a : المؤشر] توزيع السكان حسب الحالة الزواجية والمنطقة (41 chars) -> توزيع السكان حسب الحالة الزواجية والمنطقة (%) (45 chars)
# FIX VAL: [Population_7_a : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (42 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_a : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_b
#
# FIX VAL: [Population_7_b : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (42 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_8_a
#
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_8_b
#
# FIX VAL: [Population_8_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_9_a
#
# Processing Population_9_b
#
# Processing Population_10_a
#
# Processing Population_10_b
#
# Processing Population_11
#
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# Processing Population_12_a
#
# Processing Population_12_b
#
# Processing Population_13_a
#
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# Processing Population_13_b
#
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# Processing Population_14
#
# Processing Population_15
#
# Processing Population_16
#
# Processing Population_17
#
# FIX VAL: [Population_17 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_18
#
# Processing Population_18_a
#
# Processing Population_18_b
#
# Processing Population_19_a
#
# Processing Population_19_b
#
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_20_a
#
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_20_b
#
# FIX VAL: [Population_20_b : المؤشر] معدل وفيات الأطفال دون سن الخامسة (لكل 1000 ولادة حية) حسب المنطقة (66 chars) -> معدل وفيات الأطفال دون سن الخامسة (لكل 1,000 ولادة حية) حسب المنطقة (67 chars)
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_21_a
#
# FIX VAL: [Population_21_a : المؤشر] معدل وفيات الأطفال ( 1-4 سنوات) حسب المواطنة (44 chars) -> معدل وفيات الأطفال (1-4 سنوات) حسب المواطنة (43 chars)
# Processing Population_21_b
#
# FIX VAL: [Population_21_b : المؤشر] معدل وفيات الأطفال ( 1-4 سنوات) حسب المنطقة (43 chars) -> معدل وفيات الأطفال (1-4 سنوات) حسب المنطقة (42 chars)
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_22
#
# Processing Population_23_a
#
# FIX VAL: [Population_23_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الغدد الصم أو أمراض التغذية و أمراض الاستقلاب (51 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# Processing Population_23_b
#
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الغدد الصم أو أمراض التغذية أو أمراض الاستقلاب (52 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
#
#  -----------------------------Processing Egypt population.xlsx----------------------------------------
# Processing Population_21_a
#
# Processing Population_22
#
# Processing Population_23_a
#
# FIX VAL: [Population_23_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# Processing Population_23_b
#
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# Processing Population_20_b
#
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_21_b
#
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_20_a
#
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_15
#
# Processing Population_18_b
#
# Processing Population_19_b
#
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_19_a
#
# Processing Population_13_a
#
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# Processing Population_18_a
#
# Processing Population_13_b
#
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# Processing Population_18
#
# Processing Population_14
#
# Processing Population_16
#
# Processing Population_17
#
# FIX VAL: [Population_17 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_9_a
#
# Processing Population_8_b
#
# FIX VAL: [Population_8_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_9_b
#
# Processing Population_12_a
#
# Processing Population_7_b2
#
# FIX VAL: [Population_7_b2 : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (%) (46 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_10_a
#
# Processing Population_4
#
# Processing Population_2
#
# Processing Population_12_b
#
# Processing Population_7_a2
#
# FIX VAL: [Population_7_a2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_1_b
#
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_10_b
#
# Processing Population_7_b1
#
# FIX VAL: [Population_7_b1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_3
#
# Processing Population_5_b
#
# Processing Population_6_a
#
# Processing Population_1_a
#
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_5_a
#
# Processing Population_6_b
#
# Processing Population_7_a1
#
# FIX VAL: [Population_7_a1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_8_a
#
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_11
#
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
#
#  -----------------------------Processing Iraq population.xlsx----------------------------------------
# Processing Population_21_b
#
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_20_b
#
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_21_a
#
# Processing Population_22
#
# Processing Population_23_b
#
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# Processing Population_20_a
#
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_23_a
#
# FIX VAL: [Population_23_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# Processing Population_19_b
#
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_18_b
#
# Processing Population_17
#
# FIX VAL: [Population_17 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_18
#
# Processing Population_15
#
# Processing Population_13_a
#
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# Processing Population_14
#
# Processing Population_13_b
#
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# Processing Population_12_b
#
# Processing Population_12_a
#
# Processing Population_11
#
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# Processing Population_9_b
#
# Processing Population_10_a
#
# Processing Population_10_b
#
# Processing Population_9_a
#
# Processing Population_8_b
#
# FIX VAL: [Population_8_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_8_a
#
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_7_b1
#
# FIX VAL: [Population_7_b1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_a2
#
# FIX VAL: [Population_7_a2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_a1
#
# FIX VAL: [Population_7_a1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_b2
#
# FIX VAL: [Population_7_b2 : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (%) (46 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_6_b
#
# Processing Population_6_a
#
# Processing Population_5_b
#
# Processing Population_5_a
#
# Processing Population_4
#
# Processing Population_3
#
# Processing Population_2
#
# Processing Population_19_a
#
# Processing Population_18_a
#
# Processing Population_1_b
#
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_16
#
# Processing Population_1_a
#
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
#
#  -----------------------------Processing jordan population.xlsx----------------------------------------
# Processing Population_20_a
#
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_18_b
#
# Processing Population_21_a
#
# Processing Population_23_b
#
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# Processing Population_21_b
#
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_12_a
#
# Processing Population_9_b
#
# Processing Population_10_b
#
# Processing Population_17
#
# Processing Population_18_a
#
# Processing Population_22
#
# Processing Population_19_b
#
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_23_a
#
# FIX VAL: [Population_23_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# Processing Population_12_b
#
# Processing Population_14
#
# Processing Population_16
#
# Processing Population_18
#
# Processing Population_15
#
# Processing Population_19_a
#
# Processing Population_13_b
#
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# Processing Population_20_b
#
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_11
#
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# Processing Population_7_b2
#
# FIX VAL: [Population_7_b2 : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (%) (46 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_13_a
#
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# Processing Population_9_a
#
# Processing Population_10_a
#
# Processing Population_8_b
#
# Processing Population_7_a1
#
# FIX VAL: [Population_7_a1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_8_a
#
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_7_a2
#
# FIX VAL: [Population_7_a2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_b1
#
# FIX VAL: [Population_7_b1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_6_b
#
# Processing Population_6_a
#
# Processing Population_5_b
#
# Processing Population_5_a
#
# Processing Population_4
#
# Processing Population_3
#
# Processing Population_2
#
# Processing Population_1_a
#
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_1_b
#
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
#
#  -----------------------------Processing Kuwait Population.xlsx----------------------------------------
# Processing Population_1_a
#
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_1_b
#
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_2
#
# Processing Population_3
#
# Processing Population_4
#
# Processing Population_5_a
#
# Processing Population_5_b
#
# Processing Population_6_a
#
# Processing Population_6_b
#
# Processing Population_7_a1
#
# FIX VAL: [Population_7_a1 : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (42 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_a2
#
# ...
# Processing Population_20_a
#
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_20_b
#
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_21_a
#
# Processing Population_21_b
#
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_22
#
# Processing Population_23_a
#
# FIX VAL: [Population_23_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# Processing Population_23_b
#
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
#
#  -----------------------------Processing United Arab Emirates Population.xlsx----------------------------------------
# Processing Population_1_a
#
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_1_b
#
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_2
#
# Processing Population_3
#
# Processing Population_4
#
# Processing Population_5_a
#
# Processing Population_5_b
#
# Processing Population_6_a
#
# Processing Population_6_b
#
# Processing Population_7_a1
#
# FIX VAL: [Population_7_a1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_a2
#
# FIX VAL: [Population_7_a2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_b1
#
# FIX VAL: [Population_7_b1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_b2
#
# FIX VAL: [Population_7_b2 : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (%) (46 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_8_a
#
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_8_b
#
# FIX VAL: [Population_8_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_9_a
#
# Processing Population_9_b
#
# Processing Population_10_a
#
# Processing Population_10_b
#
# Processing Population_11
#
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# Processing Population_12_a
#
# Processing Population_12_b
#
# Processing Population_13_a
#
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# Processing Population_13_b
#
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# Processing Population_14
#
# Processing Population_15
#
# Processing Population_16
#
# Processing Population_17
#
# FIX VAL: [Population_17 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_18
#
# Processing Population_18_a
#
# Processing Population_18_b
#
# Processing Population_19_a
#
# Processing Population_19_b
#
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_20_a
#
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_20_b
#
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_21_a
#
# Processing Population_21_b
#
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_22
#
# Processing Population_23_a
#
# FIX VAL: [Population_23_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# Processing Population_23_b
#
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
#
#  -----------------------------Processing Yemen Population.xlsx----------------------------------------
# Processing Population_1_a
#
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_1_b
#
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_2
#
# Processing Population_3
#
# Processing Population_4
#
# Processing Population_5_a
#
# Processing Population_5_b
#
# Processing Population_6_a
#
# Processing Population_6_b
#
# Processing Population_7_a1
#
# FIX VAL: [Population_7_a1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_a2
#
# FIX VAL: [Population_7_a2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_b1
#
# FIX VAL: [Population_7_b1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_7_b2
#
# FIX VAL: [Population_7_b2 : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (%) (46 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# Processing Population_8_a
#
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_8_b
#
# FIX VAL: [Population_8_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_9_a
#
# Processing Population_9_b
#
# Processing Population_10_a
#
# Processing Population_10_b
#
# Processing Population_11
#
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# Processing Population_12_a
#
# Processing Population_12_b
#
# Processing Population_13_a
#
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# Processing Population_13_b
#
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# Processing Population_14
#
# Processing Population_15
#
# Processing Population_16
#
# Processing Population_17
#
# FIX VAL: [Population_17 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_18
#
# Processing Population_18_a
#
# Processing Population_18_b
#
# Processing Population_19_a
#
# Processing Population_19_b
#
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_20_a
#
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_20_b
#
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_21_a
#
# Processing Population_21_b
#
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# Processing Population_22
#
# Processing Population_23_a
#
# FIX VAL: [Population_23_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# Processing Population_23_b
#
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# ########################################

# %% [markdown]
# ### Processing the not received questionnaires

# %%
# folders=['Population', 'Labor','Housing','Education','Health','Poverty']
# main_path='C:/Users/raffi/OneDrive - United Nations/Desktop/DSS/DATA COLLECTOR/datacollector_notreceived_quest'
# # folder_path='C:/Users/raffi/OneDrive - United Nations/Desktop/DSS/DATA COLLECTOR'

# for folder in folders:
#     folder_path=f'{main_path}/{folder}'
#     # Get all excel files in the directory
#     xlsx_files = [f for f in os.listdir(folder_path) if f.endswith('.xlsx')]

#     print(f'Processing {folder}')
#     print('//////////////////////////////////////// \n')

#     dataframes = []

#     category_map = {
#         'housing': 'سكن',
#         'population': 'سكان',
#         'labor': 'عمالة',
#         'education': 'التعليم',
#         'poverty': 'الفقر',
#         'health': 'الصحة'
#     }

#     #adding الفصل to the dictionary
#     Ar_En_dictionary['الفصل'] = {'dim_values': {v: k for k, v in category_map.items()}}

#     for file in xlsx_files:
#         xls = pd.ExcelFile(os.path.join(folder_path, file))
        
#         for sheet_name in xls.sheet_names:
#             df_raw = pd.read_excel(xls, sheet_name=sheet_name, header=None, dtype=str)
#             header_rows = df_raw.index[df_raw[0] == 'index'].tolist()
#             if len(header_rows) < 2: continue

#             # 1. prepare the data and source slices
#             df_data = df_raw[df_raw[0] == '1'].copy()
#             df_data.columns = df_raw.iloc[header_rows[0]].dropna().str.strip()
#             # Drop index now
#             df_data = df_data.drop(columns=['index'], errors='ignore')
            
#             df_source = df_raw[df_raw[0] == '2'].copy()
#             df_source = df_source[df_raw.iloc[header_rows[1]].dropna().str.strip().index]
#             df_source.columns = df_raw.iloc[header_rows[1]].dropna().str.strip()
#             # Drop index now
#             df_source = df_source.drop(columns=['index'], errors='ignore')

#             ###########################################################################################
#             # Extract category and add 'الفصل' column
#             def extract_category(sheet_name):
#                 # Normalize: if there is a '-', take the part after it, otherwise use the whole name
#                 target = sheet_name.split('-')[-1].strip()
        
#                 # Now extract the part before the underscore (if it exists)
#                 return target.split('_')[0].strip().lower()

#             raw_cat = extract_category(sheet_name)

#             # If raw_cat is not in keys, try to find the best match using difflib
#             if raw_cat not in category_map.keys():
#                 matches = difflib.get_close_matches(raw_cat, category_map.keys(), n=1, cutoff=0.6)
#                 if matches:
#                     best_match = matches[0]
#                     print(f"  >> FIX CATEGORY: {raw_cat} -> {best_match}")
#                     raw_cat = best_match
#                 else:
#                     print(f'  !!! ERROR: Could not identify category for {raw_cat} from {file}')

#             # Assign the value based on the (potentially fixed) raw_cat
#             df_data['الفصل'] = category_map.get(raw_cat, raw_cat)

#             ########################################################################################################
        
#             # --- 3. merge data with source ---
#             # id_vars are all non-digit columns (Indicator, Country, Chapter, etc.)
#             id_vars = [c for c in df_data.columns if not str(c).isdigit()]
#             # year_columns are only the digit columns (2010, 2011, etc.)
#             year_columns = [c for c in df_data.columns if str(c).isdigit()]
            
#             #DEBUG############
#             # print(sheet_name)
#             #DEBUG############

#             df_melted = df_data.melt(
#                 id_vars=id_vars, 
#                 value_vars=year_columns, 
#                 var_name='السنة', 
#                 value_name='العدد'
#             )

#             # CRASH LOCATOR BLOCK
#             try:
#                 # Merge melted data with source info
#                 df_merged = pd.merge(df_melted, df_source, on=['السنة', 'المؤشر', 'الدولة'], how='left')
                
                
#             except KeyError as e:
#                 print("\n" + "="*50)
#                 print(f"💥 CRASH DETECTED IN WORKBOOK: {file}")
#                 print(f"💥 ON SHEET: {sheet_name}")
#                 print(f"💥 FOR CHAPTER ('الفصل'): {df_data['الفصل'].iloc[0] if 'الفصل' in df_data.columns else 'Unknown'}")
#                 print("="*50)
#                 print(f"Columns actually found in df_data:\n{list(df_data.columns)}\n")
#                 print(f"Columns actually found in df_source:\n{list(df_source.columns)}")
#                 print("="*50)
#                 raise e
            
#             ###############################################################################################################        
#             # --- CLEANING BLOCK ---

#             # Added 'الفصل' to keep it from being changed/fixed
#             standard_cols = {'السنة', 'العدد', 'المصدر', 'الفصل'}
            
#             # 1. Column Name Cleanup
#             search_targets = list(standard_cols) + list(Ar_En_dictionary.keys())
            
#             for col in list(df_merged.columns):
#                 match = difflib.get_close_matches(str(col), search_targets, n=1, cutoff=0.6)
#                 if match and match[0] != col:
#                     best_match = match[0]
#                     print(f"  >> FIX COL: {sheet_name} : {col}({len(str(col))} chars) -> {best_match} ({len(str(best_match))} chars)")
#                     df_merged.rename(columns={col: best_match}, inplace=True)
                    
#             # 2. Cell Value Cleanup
#             for col in df_merged.columns:
#                 # Note: Ensuring column exists in dict to avoid KeyError
#                 if col in Ar_En_dictionary:
#                     allowed_vals = [str(k) for k in Ar_En_dictionary[col]['dim_values'].keys()]
                    
#                     for val in df_merged[col].unique():
#                         if str(val) not in allowed_vals:
#                             v_match = difflib.get_close_matches(str(val), allowed_vals, n=1, cutoff=0.6)
#                             if v_match and v_match[0] != str(val):
#                                 print(f"FIX VAL: [{sheet_name} : {col}] {val} ({len(str(val))} chars) -> {v_match[0]} ({len(str(v_match[0]))} chars)")
#                                 df_merged[col] = df_merged[col].replace(val, v_match[0])
#                 else:
#                     print(f'{col} was not found in the dictionary')

#             #append to the dataframes
#             dataframes.append(df_merged)
                                
#             ########################################################################################################
#     # Final aggregation
#     path='C:/Users/raffi/OneDrive - United Nations/Desktop/DSS/COMPENDIUM-ARAB SOCIETY'

#     final_df = pd.concat(dataframes, ignore_index=True)
    
#     # One last safety strip in case different sheets had different trailing spaces 
#     # that survived the merge or concat
#     final_df.columns = final_df.columns.str.strip()
    
#     final_df = final_df.dropna(axis=1, how='all')
#     final_df.to_excel(path+f'/{folder}_AR_Notreplied.xlsx', index=False)

#     print('########################################\n\n')

# %% [markdown]
# ### check all the column names if they are  unique

# %%
# import difflib

# cols = list(final_df.columns)
# threshold = 0.9

# for col in cols:
#     # Find everything in the list that is "close enough" to the current column
#     # By setting it to len(cols), you are telling Python: "Don't stop at 3 (default),
#     # show me every single match you find in the entire list."
#     matches = difflib.get_close_matches(col, cols, n=len(cols), cutoff=threshold)
    
#     # If it found more than itself, you have a duplicate issue
#     if len(matches) > 1:
#         print(f"Similarity found for '{col}': {matches}")

# %% [markdown]
# ### check unique values in columns

# %%
# import difflib

# # Keep THRESHOLD very high to only catch typos/spaces, not different indicators
# THRESHOLD = 0.98 
# fuzzy_report = {}

# # Compare each value with every other value in the list
# '''enumerate(values): This gives you two things at once: the index i (the position) and the val1 (the actual text, like "الجزائر").
# This loop picks the "Anchor" item. We are going to hold this item in our hand and compare it to others.'''
 
# for column, values in Ar_En_dictionary.items():
#     similar_pairs = []
    
#     # FIX: Convert 'values' to a list so Python knows how to slice it properly
#     values_list = list(values)

#     for i, val1 in enumerate(values_list):
#         for val2 in values_list[i+1:]:
#             # Use raw strings to catch hidden spaces
#             s1, s2 = str(val1), str(val2)
#             score = difflib.SequenceMatcher(None, s1, s2).ratio()
            
#             #Only show if they are ALMOST identical but NOT exactly 1.0
#             if score >= THRESHOLD and score < 1.0:
#                 # Get the sources
#                 src1 = final_df[final_df[column] == val1]['file_source'].unique().tolist()
#                 src2 = final_df[final_df[column] == val2]['file_source'].unique().tolist()
                
#                 # Format exactly as you requested
#                 # Wrapping values in quotes "" helps you see the trailing spaces in the terminal
#                 report_entry = f"\"{val1}\" {src1} <<<--->>> \"{val2}\" {src2}"
#                 similar_pairs.append(report_entry)
                
#     if similar_pairs:
#         fuzzy_report[column] = similar_pairs

# # Print the diagnostic report
# print(json.dumps(fuzzy_report, indent=4, ensure_ascii=False))
# Out:
# {}
