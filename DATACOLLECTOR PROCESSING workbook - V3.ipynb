# %%
import pandas as pd
import numpy as np
import os
import json
import difflib

# %% [markdown]
# ### get the dictionary dimensions and values to verify schema

# %%
path='C:/Users/raffi/OneDrive - United Nations/Desktop/DSS/DATA COLLECTOR'
df_translation=pd.read_excel(path+'/translation dict.xlsx')

''' it will create such a structure
{
    "Country": {
        "dim_values": {
            "Egypt": "مصر",
            "Lebanon": "لبنان"
        },
        "dim": {
            "Country": "البلد"
        }
    }
}'''

En_Ar_dictionary={}
#get the unique dimensions
dimensions = set(df_translation['col_en'].unique())

for dim in dimensions:
    df_dim=df_translation[df_translation['col_en'].isin([dim.lower(), dim])].copy()
    En_Ar_dictionary.update(
        {dim:{'dim_values':dict(zip(df_dim['val_en'], df_dim['val_ar'])), 
                'dim': {df_dim['col_en'].unique()[0]:df_dim['col_ar'].unique()[0]}}})

Ar_En_dictionary={}
#get the unique dimensions
dimensions = set(df_translation['col_ar'].unique())

for dim in dimensions:
    df_dim=df_translation[df_translation['col_ar'].isin([dim.lower(), dim])].copy()
    Ar_En_dictionary.update(
        {dim:{'dim_values':dict(zip(df_dim['val_ar'], df_dim['val_en'])), 
                'dim': {df_dim['col_ar'].unique()[0]:df_dim['col_en'].unique()[0]}}})

# %%
Ar_En_dictionary.keys()
# Out:
# dict_keys(['أقسام النشاط الإقتصادي', 'الفصل', 'نوع حيازة الوحدات السكنية', 'أنواع نظام التخلص من مياه الصرف الصحي', 'الجنس', 'القطاع', 'المؤشر', 'أقسام المهن الرئيسية', 'الحالة الزوجية', 'مصدر مياه الشرب', 'سبب الوفاة', 'القطاع المؤسسي', 'المرحلة التعليمية', 'مصدر الإضاءة', 'المنطقة', 'نوع مكان الإقامة', 'أسباب البقاء خارج القوى العاملة', 'التصنيف الدولي لاسباب الوفاة', 'المواطنة', 'الفئة', 'الفئة العمرية', 'وضع العمالة', 'الدولة', 'السنة', 'المصدر', 'العدد', 'نوع\xa0الخدمات/المنتجات'])

# %% [markdown]
# ### Processing the received questionnaires

# %%
# main_path='C:/Users/RSHIRINI/OneDrive - United Nations/Desktop/DSS/DATA COLLECTOR/datacollector_received_quest/recieved_quests'
#loop over folders, merge and save as separate files

folders=['Population', 'Labor','Housing','Education','Health','Poverty']
main_path='C:/Users/raffi/OneDrive - United Nations/Desktop/DSS/DATA COLLECTOR/datacollector_received_quest'
# folder_path='C:/Users/raffi/OneDrive - United Nations/Desktop/DSS/DATA COLLECTOR'

for folder in folders:
    folder_path=f'{main_path}/{folder}'
    # Get all excel files in the directory
    xlsx_files = [f for f in os.listdir(folder_path) if f.endswith('.xlsx')]

    print(f'Processing {folder}')
    print('//////////////////////////////////////// \n')

    dataframes = []

    category_map = {
        'housing': 'سكن',
        'population': 'سكان',
        'labor': 'عمالة',
        'education': 'التعليم',
        'poverty': 'الفقر',
        'health': 'الصحة'
    }

    #adding الفصل to the dictionary
    Ar_En_dictionary['الفصل'] = {'dim_values': {v: k for k, v in category_map.items()}}

    for file in xlsx_files:
        xls = pd.ExcelFile(os.path.join(folder_path, file))
        
        for sheet_name in xls.sheet_names:
            df_raw = pd.read_excel(xls, sheet_name=sheet_name, header=None, dtype=str)
            header_rows = df_raw.index[df_raw[0] == 'index'].tolist()
            if len(header_rows) < 2: continue

            # 1. prepare the data and source slices
            df_data = df_raw[df_raw[0] == '1'].copy()
            df_data.columns = df_raw.iloc[header_rows[0]].dropna().str.strip()
            # Drop index now
            df_data = df_data.drop(columns=['index'], errors='ignore')
            
            df_source = df_raw[df_raw[0] == '2'].copy()
            df_source = df_source[df_raw.iloc[header_rows[1]].dropna().str.strip().index]
            df_source.columns = df_raw.iloc[header_rows[1]].dropna().str.strip()
            # Drop index now
            df_source = df_source.drop(columns=['index'], errors='ignore')

            ###########################################################################################
            # Extract category and add 'الفصل' column
            def extract_category(sheet_name):
                # Normalize: if there is a '-', take the part after it, otherwise use the whole name
                target = sheet_name.split('-')[-1].strip()
        
                # Now extract the part before the underscore (if it exists)
                return target.split('_')[0].strip().lower()

            raw_cat = extract_category(sheet_name)

            # If raw_cat is not in keys, try to find the best match using difflib
            if raw_cat not in category_map.keys():
                matches = difflib.get_close_matches(raw_cat, category_map.keys(), n=1, cutoff=0.6)
                if matches:
                    best_match = matches[0]
                    print(f"  >> FIX CATEGORY: {raw_cat} -> {best_match}")
                    raw_cat = best_match
                else:
                    print(f'  !!! ERROR: Could not identify category for {raw_cat} from {file}')

            # Assign the value based on the (potentially fixed) raw_cat
            df_data['الفصل'] = category_map.get(raw_cat, raw_cat)

            ########################################################################################################
        
            # --- 3. merge data with source ---
            # id_vars are all non-digit columns (Indicator, Country, Chapter, etc.)
            id_vars = [c for c in df_data.columns if not str(c).isdigit()]
            # year_columns are only the digit columns (2010, 2011, etc.)
            year_columns = [c for c in df_data.columns if str(c).isdigit()]
            
            #DEBUG############
            # print(sheet_name)
            #DEBUG############

            df_melted = df_data.melt(
                id_vars=id_vars, 
                value_vars=year_columns, 
                var_name='السنة', 
                value_name='العدد'
            )

            # CRASH LOCATOR BLOCK
            try:
                # Merge melted data with source info
                df_merged = pd.merge(df_melted, df_source, on=['السنة', 'المؤشر', 'الدولة'], how='left')
                
                
            except KeyError as e:
                print("\n" + "="*50)
                print(f"💥 CRASH DETECTED IN WORKBOOK: {file}")
                print(f"💥 ON SHEET: {sheet_name}")
                print(f"💥 FOR CHAPTER ('الفصل'): {df_data['الفصل'].iloc[0] if 'الفصل' in df_data.columns else 'Unknown'}")
                print("="*50)
                print(f"Columns actually found in df_data:\n{list(df_data.columns)}\n")
                print(f"Columns actually found in df_source:\n{list(df_source.columns)}")
                print("="*50)
                raise e
            
            ###############################################################################################################        
            # --- CLEANING BLOCK ---

            # Added 'الفصل' to keep it from being changed/fixed
            standard_cols = {'السنة', 'العدد', 'المصدر', 'الفصل'}
            
            # 1. Column Name Cleanup
            search_targets = list(standard_cols) + list(Ar_En_dictionary.keys())
            
            for col in list(df_merged.columns):
                match = difflib.get_close_matches(str(col), search_targets, n=1, cutoff=0.6)
                if match and match[0] != col:
                    best_match = match[0]
                    print(f"  >> FIX COL: {sheet_name} : {col}({len(str(col))} chars) -> {best_match} ({len(str(best_match))} chars)")
                    df_merged.rename(columns={col: best_match}, inplace=True)
                    
            # 2. Cell Value Cleanup
            for col in df_merged.columns:
                # Note: Ensuring column exists in dict to avoid KeyError
                if col in Ar_En_dictionary:
                    allowed_vals = [str(k) for k in Ar_En_dictionary[col]['dim_values'].keys()]
                    
                    for val in df_merged[col].unique():
                        if str(val) not in allowed_vals:
                            v_match = difflib.get_close_matches(str(val), allowed_vals, n=1, cutoff=0.6)
                            if v_match and v_match[0] != str(val):
                                print(f"FIX VAL: [{sheet_name} : {col}] {val} ({len(str(val))} chars) -> {v_match[0]} ({len(str(v_match[0]))} chars)")
                                df_merged[col] = df_merged[col].replace(val, v_match[0])
                else:
                    print(f'{col} was not found in the dictionary')

            #append to the dataframes
            dataframes.append(df_merged)
                                
            ########################################################################################################
    # Final aggregation
    path='C:/Users/raffi/OneDrive - United Nations/Desktop/DSS/COMPENDIUM-ARAB SOCIETY'

    final_df = pd.concat(dataframes, ignore_index=True)
    
    # One last safety strip in case different sheets had different trailing spaces 
    # that survived the merge or concat
    final_df.columns = final_df.columns.str.strip()
    
    final_df = final_df.dropna(axis=1, how='all')
    final_df.to_excel(path+f'/{folder}_AR_replied.xlsx', index=False)

    print('########################################\n\n')
# Out:
# Processing Population
# ////////////////////////////////////////
#
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_17 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# FIX VAL: [Population_8_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_7_b2 : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (%) (46 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_b2 : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (42 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_8_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# FIX VAL: [Population_17 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a  : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a  : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Population_23_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# FIX VAL: [Population_17 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_8_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_7_b2 : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (%) (46 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# FIX VAL: [Iraq population - Population_1_ : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Iraq population - Population__1 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Iraq population - Population_7_ : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (%) (46 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Iraq population - Population_7_ : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Iraq population - Population_7_ : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Iraq population - Population_7_ : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Iraq population - Population_7_ : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Iraq population - Population__4 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Iraq population - Population__4 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Iraq population - Population__4 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Iraq population - Population__4 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Iraq population - Population__5 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Iraq population - Population__5 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Iraq population - Population__5 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Iraq population - Population__5 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Iraq population - Population__6 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Iraq population - Population__6 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Iraq population - Population__6 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Iraq population - Population__6 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Iraq population - Population_8_ : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Iraq population - Population__7 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Iraq population - Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Iraq population - Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Iraq population - Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Iraq population - Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Iraq population - Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Iraq population - Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Iraq population - Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Iraq population - Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# FIX VAL: [Iraq population - Population_14 : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# FIX VAL: [Iraq population - Population_17 : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# FIX VAL: [Iraq population - Population_22 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Iraq population - Population_24 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Iraq population - Population_24 : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Iraq population - Population_24 : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Iraq population - Population_24 : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Iraq population - Population_24 : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Iraq population - Population_24 : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Iraq population - Population_24 : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Iraq population - Population_24 : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Iraq population - Population_24 : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Iraq population - Population_24 : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Iraq population - Population_24 : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Iraq population - Population_25 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Iraq population - Population_26 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Iraq population - Population_26 : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Iraq population - Population_26 : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Iraq population - Population_26 : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Iraq population - Population_28 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Iraq population - Population_30 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Iraq population - Population_31 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# FIX VAL: [Population_7_b2 : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (%) (46 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_17 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# FIX VAL: [Population_8_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_7_b2 : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (%) (46 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_17 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Population_23_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Population_8_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_7_b2 : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (%) (46 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أسباب خارجية للمرض والوَفيات (28 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_17 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_b2 : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (%) (46 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a1 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_8_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a2 : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_17 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# FIX VAL: [Population_23_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الدم والأعضاء المكوِّنة للدم وبعض الاضطرابات التي تشمل آلية المناعة (73 chars) -> أمراض الدَّم وأعضاء تكوين الدم واضطرابات معينة تشمل اضطرابات المناعة (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الغدد الصماء أو أمراض التغذية و أمراض الاستقلاب (53 chars) -> أمراض الغدد الصماء أو أمراض التغذية أو أمراض الاستقلاب (54 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] اضطِرابات نَفسيَّة أو سُلوكيَّة (31 chars) -> اضطِرابات نَفسيَّة أو سُلوكيَّة أو اضطرابات النماء العصبي (57 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجلد والنسيج تحت الجلد (29 chars) -> أَمرَاض الجِلد والنسيج تحت الجلد (32 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أمراض الجِهاز العضلي الهَيكَلي والنسِيج الضَّام (47 chars) -> أمراض الجِهاز العضلي الهَيكَلي أو النسِيج الضَّام (49 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الحَمْل، الولادة والنِّفاس (26 chars) -> الحَمْل أو الولادة أو النِّفاس (30 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] الأعراض والعلامات والنتائج السريرية والمخبرية غير الطبيعية، غير مصنّفة في موضع آخر (82 chars) -> أعراض وعلامات نتائج اكلينكية معملية غير عادية وغير مصنفة في مكان آخر (68 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] إصابات أو تسمُّمَات أو بعض العواقب الأخرى لأسباب خارجية (55 chars) -> إصابات أو تسمُّمَات أو بعض عواقب أخرى لأسباب خارجية (51 chars)
# FIX VAL: [Population_23_a : سبب الوفاة] أسباب خارجية للمرضَ والوَفيات (29 chars) -> أسباب خارجية للمراضَة والوَفيات (31 chars)
# FIX VAL: [Population_23_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_23_b : سبب الوفاة] أمراض الأذن والنَّاتئ الخُشَّائي (32 chars) -> أمراض الأذن والنَّاتئ الخُشَّائي (الحَلَمي) (43 chars)
# ...
# FIX VAL: [Labor_3_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Labor_3_a : المؤشر] الأفراد خارج القوى العاملة حسب الفئة العمرية (44 chars) -> الأفراد خارج القوى العاملة حسب الفئة العمرية  (45 chars)
# FIX VAL: [Labor_3_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Labor_2 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Labor_1 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia labor - Labor_3_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia labor - Labor_3_a : المؤشر] الأفراد خارج القوى العاملة حسب الفئة العمرية (44 chars) -> الأفراد خارج القوى العاملة حسب الفئة العمرية  (45 chars)
# FIX VAL: [Tunisia labor - Labor_3_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia labor - Labor_2 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia labor - Labor_1 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia labor - Labor_4 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia labor - Labor_6 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia labor - Labor_5 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia labor - Labor_7 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia labor - Labor_8 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia labor - Labor_9 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia labor - Labor_10 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# ########################################
#
#
# Processing Housing
# ////////////////////////////////////////
#
# FIX VAL: [Housing_8 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Housing_6 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Housing_8 : المؤشر] نسبة الأفراد الذين يملكون الهاتف المحمول (4 سنوات فأكثر) (56 chars) -> نسبة الأفراد الذين يملكون الهاتف المحمول (40 chars)
# FIX VAL: [Housing_8 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Housing_6 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Iraq_housing - Housing_4 : المؤشر] أنواع نظام تصريف مياه  المجاري (نسبة مئوية من مجموع الوحدات السكنية) (68 chars) -> أنواع نظام تصريف مياه المجاري (نسبة مئوية من مجموع الوحدات السكنية) (67 chars)
# FIX VAL: [Iraq_housing - Housing_8 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Iraq_housing - Housing_6 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Housing_8 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Housing_6 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Housing_4 : المؤشر] أنواع نظام تصريف مياه  المجاري (نسبة مئوية من مجموع الوحدات السكنية) (68 chars) -> أنواع نظام تصريف مياه المجاري (نسبة مئوية من مجموع الوحدات السكنية) (67 chars)
# FIX VAL: [Housing_8 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Housing_6 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Housing_4 : المؤشر] أنواع نظام تصريف مياه  المجاري (نسبة مئوية من مجموع الوحدات السكنية) (68 chars) -> أنواع نظام تصريف مياه المجاري (نسبة مئوية من مجموع الوحدات السكنية) (67 chars)
# 67.8 was not found in the dictionary
# 52.3 was not found in the dictionary
# FIX VAL: [Housing_8 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Housing_6 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Housing_4 : أنواع نظام التخلص من مياه الصرف الصحي] تصريف مياه الصرف الصحي إلى نظام مجاري متصل بنظام تخلص فردي لمياه الصرف الصحي (صهريج صرف صحي، بئر امتصاص)  (105 chars) -> تصريف مياه الصرف الصحي إلى نظام مجاري متصل بنظام تخلص فردي لمياه الصرف الصحي (صهريج صرف صحي، بئر امتصاص) (104 chars)
# FIX VAL: [Housing_8 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Housing_6 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Housing_4 : المؤشر] أنواع نظام تصريف مياه  المجاري (نسبة مئوية من مجموع الوحدات السكنية) (68 chars) -> أنواع نظام تصريف مياه المجاري (نسبة مئوية من مجموع الوحدات السكنية) (67 chars)
# FIX VAL: [Housing_8 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Housing_6 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Housing_4 : المؤشر] أنواع نظام تصريف مياه  المجاري (نسبة مئوية من مجموع الوحدات السكنية) (68 chars) -> أنواع نظام تصريف مياه المجاري (نسبة مئوية من مجموع الوحدات السكنية) (67 chars)
# FIX VAL: [Housing_4 : أنواع نظام التخلص من مياه الصرف الصحي] تصريف مياه الصرف الصحي إلى نظام مجاري متصل بمحطة معالجة الصرف الصحي العامة* (75 chars) -> تصريف مياه الصرف الصحي إلى نظام مجاري متصل بمحطة معالجة الصرف الصحي العامة (74 chars)
# FIX VAL: [Tunisia housing - Housing_8 : المؤشر] نسبة الأفراد الذين يملكون الهاتف المحمول  (41 chars) -> نسبة الأفراد الذين يملكون الهاتف المحمول (40 chars)
# FIX VAL: [Tunisia housing - Housing_8 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia housing - Housing_6 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# ########################################
#
#
# Processing Education
# ////////////////////////////////////////
#
# FIX VAL: [Education_4 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_3 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_c : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_c : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_4 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_3 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_c : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_c : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_c : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_4 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_3 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_c : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_c : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_4 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_c : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_3 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_c : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_3 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_4 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_c : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_c : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_4 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_3 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_c : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_c : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_3 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_4 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_c : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_2_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_c : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Education_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia education - Education_1 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia education - Education_2 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia education - Education_3 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia education - Education_4 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia education - Education_5 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia education - Education_6 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia education - Education_7 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Tunisia education - Education_8 : الجنس]  إناث (5 chars) -> إناث (4 chars)
#   >> FIX CATEGORY: educatio -> education
# ########################################
#
#
# Processing Health
# ////////////////////////////////////////
#
# FIX VAL: [Health_12 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_11_b : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_11_a : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_10 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_2_a : المؤشر] الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية)) حسب المواطنة (74 chars) -> الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية) حسب المواطنة (73 chars)
# FIX VAL: [Health_2_a : المؤشر] الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية)) حسب المواطنة (74 chars) -> الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية) حسب المواطنة (73 chars)
# FIX VAL: [Health_10 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_11_a : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_11_b : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_12 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_11_b : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_12 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_11_a : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_10 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_2_a : المؤشر] الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية)) حسب المواطنة (74 chars) -> الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية) حسب المواطنة (73 chars)
# FIX VAL: [Iraq health - Health_2_a : المؤشر] الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية)) حسب المواطنة (74 chars) -> الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية) حسب المواطنة (73 chars)
# FIX VAL: [Iraq health - Health_11_b : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Iraq health - Health_11_a : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Iraq health - Health_10 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Iraq health - Health_12 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_12 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_11_b : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_11_a : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_10 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_2_a : المؤشر] الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية)) حسب المواطنة (74 chars) -> الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية) حسب المواطنة (73 chars)
# FIX VAL: [Health_2_a : المواطنة] غير مواطنين  (12 chars) -> غير مواطنين (11 chars)
# FIX VAL: [Libya health - Health_2_a : المؤشر] الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية)) حسب المواطنة (74 chars) -> الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية) حسب المواطنة (73 chars)
# FIX VAL: [Libya health - Health_12 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Libya health - Health_10 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Libya health - Health_11_b : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Libya health - Health_11_a : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Libya health1 - Health_2_a : المؤشر] الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية)) حسب المواطنة (74 chars) -> الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية) حسب المواطنة (73 chars)
# FIX VAL: [Libya health1 - Health_11_b : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Libya health1 - Health_10 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Libya health1 - Health_12 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Libya health1 - Health_11_a : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_12 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_11_b : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_11_a : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_10 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_2_a : المؤشر] الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية)) حسب المواطنة (74 chars) -> الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية) حسب المواطنة (73 chars)
# FIX VAL: [Health_11_b : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_12 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_10 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_11_a : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_2_a : المؤشر] الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية)) حسب المواطنة (74 chars) -> الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية) حسب المواطنة (73 chars)
# FIX VAL: [Health_12 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_11_b : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_10 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_11_a : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Health_2_a : المؤشر] الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية)) حسب المواطنة (74 chars) -> الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية) حسب المواطنة (73 chars)
# FIX VAL: [Tunisia health - Health_2_a : المؤشر] الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية)) حسب المواطنة (74 chars) -> الولادات التي يشرف عليها أخصائيون صحّيون مَهَرة (نسبة مئوية) حسب المواطنة (73 chars)
# FIX VAL: [Tunisia health - Health_11_b : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Tunisia health - Health_11_a : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Tunisia health - Health_10 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# FIX VAL: [Tunisia health - Health_12 : الفئة العمرية] 15-24 (5 chars) -> 15-24 سنة (9 chars)
# ########################################
#
#
# Processing Poverty
# ////////////////////////////////////////
#
# 2024.1 was not found in the dictionary
# FIX VAL: [Poverty_2 : المؤشر] مؤشر جيني  (10 chars) -> مؤشر جيني (9 chars)
# 2024.1 was not found in the dictionary
# FIX VAL: [Poverty_2 (2) : المؤشر] مؤشر جيني  (10 chars) -> مؤشر جيني (9 chars)
#   >> FIX COL: Tunisia_poverty - Poverty_5 : نوع الخدمات/المنتجات(20 chars) -> نوع الخدمات/المنتجات (20 chars)
# ########################################

# %% [markdown]
# ### Processing the not received questionnaires

# %%
folders=['Population', 'Labor','Housing','Education','Health','Poverty']
main_path='C:/Users/raffi/OneDrive - United Nations/Desktop/DSS/DATA COLLECTOR/datacollector_notreceived_quest'
# folder_path='C:/Users/raffi/OneDrive - United Nations/Desktop/DSS/DATA COLLECTOR'

for folder in folders:
    folder_path=f'{main_path}/{folder}'
    # Get all excel files in the directory
    xlsx_files = [f for f in os.listdir(folder_path) if f.endswith('.xlsx')]

    print(f'Processing {folder}')
    print('//////////////////////////////////////// \n')

    dataframes = []

    category_map = {
        'housing': 'سكن',
        'population': 'سكان',
        'labor': 'عمالة',
        'education': 'التعليم',
        'poverty': 'الفقر',
        'health': 'الصحة'
    }

    #adding الفصل to the dictionary
    Ar_En_dictionary['الفصل'] = {'dim_values': {v: k for k, v in category_map.items()}}

    for file in xlsx_files:
        xls = pd.ExcelFile(os.path.join(folder_path, file))
        
        for sheet_name in xls.sheet_names:
            df_raw = pd.read_excel(xls, sheet_name=sheet_name, header=None, dtype=str)
            header_rows = df_raw.index[df_raw[0] == 'index'].tolist()
            if len(header_rows) < 2: continue

            # 1. prepare the data and source slices
            df_data = df_raw[df_raw[0] == '1'].copy()
            df_data.columns = df_raw.iloc[header_rows[0]].dropna().str.strip()
            # Drop index now
            df_data = df_data.drop(columns=['index'], errors='ignore')
            
            df_source = df_raw[df_raw[0] == '2'].copy()
            df_source = df_source[df_raw.iloc[header_rows[1]].dropna().str.strip().index]
            df_source.columns = df_raw.iloc[header_rows[1]].dropna().str.strip()
            # Drop index now
            df_source = df_source.drop(columns=['index'], errors='ignore')

            ###########################################################################################
            # Extract category and add 'الفصل' column
            def extract_category(sheet_name):
                # Normalize: if there is a '-', take the part after it, otherwise use the whole name
                target = sheet_name.split('-')[-1].strip()
        
                # Now extract the part before the underscore (if it exists)
                return target.split('_')[0].strip().lower()

            raw_cat = extract_category(sheet_name)

            # If raw_cat is not in keys, try to find the best match using difflib
            if raw_cat not in category_map.keys():
                matches = difflib.get_close_matches(raw_cat, category_map.keys(), n=1, cutoff=0.6)
                if matches:
                    best_match = matches[0]
                    print(f"  >> FIX CATEGORY: {raw_cat} -> {best_match}")
                    raw_cat = best_match
                else:
                    print(f'  !!! ERROR: Could not identify category for {raw_cat} from {file}')

            # Assign the value based on the (potentially fixed) raw_cat
            df_data['الفصل'] = category_map.get(raw_cat, raw_cat)

            ########################################################################################################
        
            # --- 3. merge data with source ---
            # id_vars are all non-digit columns (Indicator, Country, Chapter, etc.)
            id_vars = [c for c in df_data.columns if not str(c).isdigit()]
            # year_columns are only the digit columns (2010, 2011, etc.)
            year_columns = [c for c in df_data.columns if str(c).isdigit()]
            
            #DEBUG############
            # print(sheet_name)
            #DEBUG############

            df_melted = df_data.melt(
                id_vars=id_vars, 
                value_vars=year_columns, 
                var_name='السنة', 
                value_name='العدد'
            )

            # CRASH LOCATOR BLOCK
            try:
                # Merge melted data with source info
                df_merged = pd.merge(df_melted, df_source, on=['السنة', 'المؤشر', 'الدولة'], how='left')
                
                
            except KeyError as e:
                print("\n" + "="*50)
                print(f"💥 CRASH DETECTED IN WORKBOOK: {file}")
                print(f"💥 ON SHEET: {sheet_name}")
                print(f"💥 FOR CHAPTER ('الفصل'): {df_data['الفصل'].iloc[0] if 'الفصل' in df_data.columns else 'Unknown'}")
                print("="*50)
                print(f"Columns actually found in df_data:\n{list(df_data.columns)}\n")
                print(f"Columns actually found in df_source:\n{list(df_source.columns)}")
                print("="*50)
                raise e
            
            ###############################################################################################################        
            # --- CLEANING BLOCK ---

            # Added 'الفصل' to keep it from being changed/fixed
            standard_cols = {'السنة', 'العدد', 'المصدر', 'الفصل'}
            
            # 1. Column Name Cleanup
            search_targets = list(standard_cols) + list(Ar_En_dictionary.keys())
            
            for col in list(df_merged.columns):
                match = difflib.get_close_matches(str(col), search_targets, n=1, cutoff=0.6)
                if match and match[0] != col:
                    best_match = match[0]
                    print(f"  >> FIX COL: {sheet_name} : {col}({len(str(col))} chars) -> {best_match} ({len(str(best_match))} chars)")
                    df_merged.rename(columns={col: best_match}, inplace=True)
                    
            # 2. Cell Value Cleanup
            for col in df_merged.columns:
                # Note: Ensuring column exists in dict to avoid KeyError
                if col in Ar_En_dictionary:
                    allowed_vals = [str(k) for k in Ar_En_dictionary[col]['dim_values'].keys()]
                    
                    for val in df_merged[col].unique():
                        if str(val) not in allowed_vals:
                            v_match = difflib.get_close_matches(str(val), allowed_vals, n=1, cutoff=0.6)
                            if v_match and v_match[0] != str(val):
                                print(f"FIX VAL: [{sheet_name} : {col}] {val} ({len(str(val))} chars) -> {v_match[0]} ({len(str(v_match[0]))} chars)")
                                df_merged[col] = df_merged[col].replace(val, v_match[0])
                else:
                    print(f'{col} was not found in the dictionary')

            #append to the dataframes
            dataframes.append(df_merged)
                                
            ########################################################################################################
    # Final aggregation
    path='C:/Users/raffi/OneDrive - United Nations/Desktop/DSS/COMPENDIUM-ARAB SOCIETY'

    final_df = pd.concat(dataframes, ignore_index=True)
    
    # One last safety strip in case different sheets had different trailing spaces 
    # that survived the merge or concat
    final_df.columns = final_df.columns.str.strip()
    
    final_df = final_df.dropna(axis=1, how='all')
    final_df.to_excel(path+f'/{folder}_AR_Notreplied.xlsx', index=False)

    print('########################################\n\n')
# Out:
# Processing Population
# ////////////////////////////////////////
#
# FIX VAL: [Population_1_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_1_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_7_a : المؤشر] توزيع السكان حسب الحالة الزواجية والمنطقة (41 chars) -> توزيع السكان حسب الحالة الزواجية والمنطقة (%) (45 chars)
# FIX VAL: [Population_7_a : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_a : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_a : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_a : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_7_b : المؤشر] توزيع السكان حسب الحالة الزواجية والمواطنة (42 chars) -> توزيع السكان حسب الحالة الزواجية والمواطنة (عدد) (48 chars)
# FIX VAL: [Population_7_b : الحالة الزوجية] لم يسبق لها الزواج (18 chars) -> لم يسبق له الزواج (17 chars)
# FIX VAL: [Population_7_b : الحالة الزوجية] متزوجة (6 chars) -> متزوج (5 chars)
# FIX VAL: [Population_7_b : الحالة الزوجية] منفصلة/ مطلقة (13 chars) -> منفصل/ مطلق (11 chars)
# FIX VAL: [Population_7_b : الحالة الزوجية] ارملة (5 chars) -> ارمل (4 chars)
# FIX VAL: [Population_8_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_8_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_11 : المؤشر] معدلات الخصوبة العمرية التفصيلية  (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (87 chars) -> معدلات الخصوبة العمرية التفصيلية (عدد المواليد لكل 1,000 امرأة في الفئة العمرية 15-49) (86 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 15-19 (5 chars) -> 15-19 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 20-24 (5 chars) -> 20-24 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 25-29 (5 chars) -> 25-29 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 30-34 (5 chars) -> 30-34 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 35-39 (5 chars) -> 35-39 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 40-44 (5 chars) -> 40-44 سنة (9 chars)
# FIX VAL: [Population_11 : الفئة العمرية] 45-49 (5 chars) -> 45-49 سنة (9 chars)
# FIX VAL: [Population_13_a : المؤشر] عدد الولادات الحية المسجلة حسب المواطنة (39 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المواطنة (45 chars)
# FIX VAL: [Population_13_b : المؤشر] عدد الولادات الحية المسجلة حسب المنطقة (38 chars) -> عدد الولادات الحية المسجلة (عدد) حسب المنطقة (44 chars)
# FIX VAL: [Population_17 : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_19_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_20_a : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_20_b : المؤشر] معدل وفيات الأطفال دون سن الخامسة (لكل 1000 ولادة حية) حسب المنطقة (66 chars) -> معدل وفيات الأطفال دون سن الخامسة (لكل 1,000 ولادة حية) حسب المنطقة (67 chars)
# FIX VAL: [Population_20_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
# FIX VAL: [Population_21_a : المؤشر] معدل وفيات الأطفال ( 1-4 سنوات) حسب المواطنة (44 chars) -> معدل وفيات الأطفال (1-4 سنوات) حسب المواطنة (43 chars)
# FIX VAL: [Population_21_b : المؤشر] معدل وفيات الأطفال ( 1-4 سنوات) حسب المنطقة (43 chars) -> معدل وفيات الأطفال (1-4 سنوات) حسب المنطقة (42 chars)
# FIX VAL: [Population_21_b : الجنس]  إناث (5 chars) -> إناث (4 chars)
#
# ==================================================
# 💥 CRASH DETECTED IN WORKBOOK: Comoros_Population_Questionnaire 2025 Final.xlsx
# 💥 ON SHEET: Population_22
# 💥 FOR CHAPTER ('الفصل'): سكان
# ==================================================
# Columns actually found in df_data:
# ['عدد الوفيات والأشخاص المفقودين والأشخاص المتضررين من الكوارث لكل 100,000 شخص', 'الدولة', 'الجنس', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025', '2026', '2027', '2028', '2029', '2030', 'الفصل']
#
# Columns actually found in df_source:
# ['المؤشر', 'الدولة', 'السنة', 'المصدر']
# ==================================================
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [4], in <cell line: 5>()
#     103     print(f"Columns actually found in df_source:\n{list(df_source.columns)}")
#     104     print("="*50)
# --> 105     raise e
#     107 ###############################################################################################################
#     108 # --- CLEANING BLOCK ---
#     109
#     110 # Added 'الفصل' to keep it from being changed/fixed
#     111 standard_cols = {'السنة', 'العدد', 'المصدر', 'الفصل'}
#
# Input In [4], in <cell line: 5>()
#      90 # CRASH LOCATOR BLOCK
#      91 try:
#      92     # Merge melted data with source info
# ---> 93     df_merged = pd.merge(df_melted, df_source, on=['السنة', 'المؤشر', 'الدولة'], how='left')
#      96 except KeyError as e:
#      97     print("\n" + "="*50)
#
# File c:\Users\raffi\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)
#     167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
#     179         sort=sort,
#     180         suffixes=suffixes,
#     181         indicator=indicator,
#     182         validate=validate,
#     183     )
#     184     return op.get_result(copy=copy)
#
# File c:\Users\raffi\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py:794, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     784     raise MergeError(msg)
#     786 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#     788 (
#     789     self.left_join_keys,
#     790     self.right_join_keys,
#     791     self.join_names,
#     792     left_drop,
#     793     right_drop,
# --> 794 ) = self._get_merge_keys()
#     796 if left_drop:
#     797     self.left = self.left._drop_labels_or_levels(left_drop)
#
# File c:\Users\raffi\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py:1311, in _MergeOperation._get_merge_keys(self)
#    1307 if lk is not None:
#    1308     # Then we're either Hashable or a wrong-length arraylike,
#    1309     #  the latter of which will raise
#    1310     lk = cast(Hashable, lk)
# -> 1311     left_keys.append(left._get_label_or_level_values(lk))
#    1312     join_names.append(lk)
#    1313 else:
#    1314     # work-around for merge_asof(left_index=True)
#
# File c:\Users\raffi\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:1914, in NDFrame._get_label_or_level_values(self, key, axis)
#    1912     values = self.axes[axis].get_level_values(key)._values
#    1913 else:
# -> 1914     raise KeyError(key)
#    1916 # Check for duplicates
#    1917 if values.ndim > 1:
#
# KeyError: 'المؤشر'

# %% [markdown]
# ### check all the column names if they are  unique

# %%
import difflib

cols = list(final_df.columns)
threshold = 0.9

for col in cols:
    # Find everything in the list that is "close enough" to the current column
    # By setting it to len(cols), you are telling Python: "Don't stop at 3 (default),
    # show me every single match you find in the entire list."
    matches = difflib.get_close_matches(col, cols, n=len(cols), cutoff=threshold)
    
    # If it found more than itself, you have a duplicate issue
    if len(matches) > 1:
        print(f"Similarity found for '{col}': {matches}")

# %% [markdown]
# ### check unique values in columns

# %%
import difflib

# Keep THRESHOLD very high to only catch typos/spaces, not different indicators
THRESHOLD = 0.98 
fuzzy_report = {}

# Compare each value with every other value in the list
'''enumerate(values): This gives you two things at once: the index i (the position) and the val1 (the actual text, like "الجزائر").
This loop picks the "Anchor" item. We are going to hold this item in our hand and compare it to others.'''
 
for column, values in Ar_En_dictionary.items():
    similar_pairs = []
    
    # FIX: Convert 'values' to a list so Python knows how to slice it properly
    values_list = list(values)

    for i, val1 in enumerate(values_list):
        for val2 in values_list[i+1:]:
            # Use raw strings to catch hidden spaces
            s1, s2 = str(val1), str(val2)
            score = difflib.SequenceMatcher(None, s1, s2).ratio()
            
            #Only show if they are ALMOST identical but NOT exactly 1.0
            if score >= THRESHOLD and score < 1.0:
                # Get the sources
                src1 = final_df[final_df[column] == val1]['file_source'].unique().tolist()
                src2 = final_df[final_df[column] == val2]['file_source'].unique().tolist()
                
                # Format exactly as you requested
                # Wrapping values in quotes "" helps you see the trailing spaces in the terminal
                report_entry = f"\"{val1}\" {src1} <<<--->>> \"{val2}\" {src2}"
                similar_pairs.append(report_entry)
                
    if similar_pairs:
        fuzzy_report[column] = similar_pairs

# Print the diagnostic report
print(json.dumps(fuzzy_report, indent=4, ensure_ascii=False))
# Out:
# {}
